# %% [markdown]
# # 02 – Vertiefung: Entropie und mittlerer Binärstellenaufwand (Informationstheorie)
#
# **Vorlesungsbezug:** *01.Informationstheorie und Codierung* → **2. Informationstheorie**. Im Skript: Entropie H als Maß für den mittleren Informationsgehalt, mittlerer Binärstellenaufwand pro Zeichen.
#
# **Navigation:** [Bezug](02_Datentypen_Informationstheorie_Bezug.ipynb) | [Signalvorrat](02_Datentypen_Signalvorrat.ipynb) | Entropie & Aufwand | [← 02_Datentypen](02_Datentypen.ipynb)

# %% [markdown]
# ## Entropie und Logarithmus
#
# In der Vorlesung: Die **Entropie** (in Bit) für ein Zeichen mit Wahrscheinlichkeit \(p\) ist
#
# $$h = -\log_2(p) \quad \text{(in Bit)}$$
#
# Für mehrere Zeichen mit Wahrscheinlichkeiten \(p_1, p_2, \ldots\):
#
# $$H = -\sum_i p_i \cdot \log_2(p_i)$$
#
# Dafür brauchst du den **Zweierlogarithmus** \(\log_2\). In Python liefert ihn die Standardbibliothek **`math`** mit `math.log2(...)`. (Das Thema **Module** kommt ausführlich in **07_Module_und_Bibliotheken** – hier nutzen wir nur diese eine Funktion.)

# %%
import math

# Ein Zeichen mit Wahrscheinlichkeit p = 0.5 (z.B. faire Münze)
p = 0.5
h = -math.log2(p)
print("p = 0.5  →  h =", h, "Bit")
# Out:
# p = 0.5  →  h = 1.0 Bit

# %%
# Zwei Zeichen: p1 = 0.5, p2 = 0.5  →  H = 1 Bit
p1, p2 = 0.5, 0.5
H = -(p1 * math.log2(p1) + p2 * math.log2(p2))
print("Gleichverteilung 2 Zeichen: H =", H, "Bit")
# Out:
# Gleichverteilung 2 Zeichen: H = 1.0 Bit

# %% [markdown]
# Die Ergebnisse sind **Dezimalzahlen** – dafür ist der Datentyp **`float`** zuständig. `math.log2` liefert immer einen `float`.

# %% [markdown]
# ## Mittlerer Binärstellenaufwand
#
# In der Vorlesung: Wenn man Zeichen binär codiert, ist der **mittlere Binärstellenaufwand** (pro Zeichen) mindestens die Entropie H. Bei optimaler Codierung gilt: mittlerer Aufwand ≈ H (Bit pro Zeichen).
#
# Beispiel: Gleichverteilung über 4 Zeichen → H = 2 Bit; man braucht pro Zeichen 2 Binärstellen (z. B. 00, 01, 10, 11).

# %%
# 4 Zeichen, gleichverteilt: p_i = 1/4
H4 = -4 * (0.25 * math.log2(0.25))
print("Gleichverteilung 4 Zeichen: H =", H4, "Bit pro Zeichen (mittlerer Aufwand mindestens H)")
# Out:
# Gleichverteilung 4 Zeichen: H = 2.0 Bit pro Zeichen (mittlerer Aufwand mindestens H)

# %% [markdown]
# ## Kurz zum Vorlesungsbezug
#
# Im Kapitel **2. Informationstheorie** werden Entropie und mittlerer Codieraufwand eingeführt. Hier hast du sie mit **`float`** und **`math.log2`** nachgerechnet. So verifizierst du: Die Vorlesungsformeln lassen sich direkt in Python umsetzen – Datentypen (02) und ein kleines Modul (`math`) reichen dafür aus.

# %% [markdown]
# ---
#
# **Zurück:** [← 02_Datentypen](02_Datentypen.ipynb) | [Bezug Informationstheorie](02_Datentypen_Informationstheorie_Bezug.ipynb) | [Signalvorrat](02_Datentypen_Signalvorrat.ipynb)
